# %% [markdown]
# # Covid 19 South Korea Patient Info

# %% [markdown]
# data from https://www.kaggle.com/kimjihoo/coronavirusdataset#PatientInfo.csv

# %%
import pandas as pd

# %%
df = pd.read_csv('./data/PatientInfo.csv', index_col=0)
df.head()
# Out:
#             global_num     sex  birth_year  age country province         city  \
# patient_id
# 1000000001         2.0    male      1964.0  50s   Korea    Seoul   Gangseo-gu
# 1000000002         5.0    male      1987.0  30s   Korea    Seoul  Jungnang-gu
# 1000000003         6.0    male      1964.0  50s   Korea    Seoul    Jongno-gu
# 1000000004         7.0    male      1991.0  20s   Korea    Seoul      Mapo-gu
# 1000000005         9.0  female      1992.0  20s   Korea    Seoul  Seongbuk-gu
#
#            disease        infection_case  infection_order   infected_by  \
# patient_id
# 1000000001     NaN       overseas inflow              1.0           NaN
# 1000000002     NaN       overseas inflow              1.0           NaN
# 1000000003     NaN  contact with patient              2.0  2.002000e+09
# 1000000004     NaN       overseas inflow              1.0           NaN
# 1000000005     NaN  contact with patient              2.0  1.000000e+09
#
# ...

# %%
from lineup_widget import LineUpWidget

df = pd.DataFrame(pd.np.random.randint(0,100,size=(100, 4)), columns=list('ABCD'))

w = LineUpWidget(df)
w
# Out:
# c:\users\sam\.virtualenvs\upsetjs_jupyter_widget-ueyvzskb\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#   This is separate from the ipykernel package so we can avoid doing imports until
# LineUpWidget(value=[], layout=Layout(align_self='stretch', height='600px'), options={'filterGlobally': True, '…

# %%
from ipywidgets import interact

def on_change(selection):
    return selection
    
interact(on_change, selection=w)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-27a5e7f01183> in <module>
#       4     return selection
#       5
# ----> 6 interact(on_change, selection=w)
#
# NameError: name 'w' is not defined
